# %% [markdown]
# <a href="https://colab.research.google.com/github/vrnTEK/Deep-Learning/blob/Assignment-0-GCB/Homework_0_Markdown_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###My first markdown cell

# %%
# My first code cell

3/2
# Out:
# 1.5

# %% [markdown]
# ##Check Following commands:
#
# Shift+Enter: Runs the code or markdown on a cell
#
# Up Arrow+Down Arrow: Toggle across cells
#
# b: Create new cell
#
# 0+0: Reset Kernel

# %% [markdown]
# #practicing Italics, Bold, inline, Blockcode and links
# 1.   _Typing Italics_
# 2.  **Typing bold**
# 3. `typing inline`
# 4. >typing blockcode
# 5. adding a [link](https://www.linkedin.com/in/varun-bhaseen-6b53b036/)

# %% [markdown]
# #Practicing types of Lists
#
# 1. Ordered lists: these are created by adding a number followed by period  and giving a space afterwards
#
# * Unordered lists or bullets are created by typing an asterisk followed by space
#
# * [X] whereas a task list is created by putting an asterisk followed by space and then typing a capital X inside a square backet
#
#     + [X] whereas a plus or minus sign can also be used for creating a sub bullter point instead of an asterisk

# %% [markdown]
# # Running code capabilities from sample colab notebook

# %%
#This is a practice file for Google colab understanding
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# #Mounting Google drive and pasting an image from drive

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#from IPython.display import Image
#Image('varun_Emoji.jpg', width=200, height=200)

#Download a file based on its file ID.

#file_id = '1mHsrebj8hcLtv70w1a5u9VQj6vF09rvF'
#open ('/content/drive/My Drive/Colab Notebooks/varun_Emoji.jpg')

#downloaded = drive.CreateFile({'id': file_id})

# %%
from IPython.display import Image
Image ('/content/drive/My Drive/Colab Notebooks/varun_Emoji.jpg')

# %% [markdown]
# #Line Magic
#
# %matplotlib inline
#
# %timeit
#
# %debug
