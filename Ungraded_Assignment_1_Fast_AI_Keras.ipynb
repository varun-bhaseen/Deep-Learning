# %% [markdown]
# <a href="https://colab.research.google.com/github/vrnTEK/Deep-Learning/blob/master/Ungraded_Assignment_1_Fast_AI_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!curl -s https://course.fast.ai/setup/colab | bash

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '12ShfzNFaxqOdwS8MPIpw5Y9gTyq8VuZZ'
downloaded = drive.CreateFile({'id': file_id})
#print('Downloaded content "{}"'.format(downloaded.GetContentString()))
downloaded.GetContentFile('Mule.txt')  
url_mule = pd.read_csv('Mule.txt')
url_mule.to_csv('Mule.csv')
url_mule

#!cp Mule.csv "drive/My Drive/Spring2020/Deep Learning/"
# Out:
#     https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTktxnPblvKHNG8JT-Y9gYV9SePexh1yxTvLjelE-TkhYEJZMDC
# 0    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4    https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                 ...
# 554  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 555  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 556  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 557  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 558  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [559 rows x 1 columns]

# %%
#downloading file for Horse

file_id = '1C-Y3uoexVQ8309wgiQruWO7UjMPGiY8p'
downloaded = drive.CreateFile({'id': file_id})

downloaded.GetContentFile('Horse.txt')  
url_horse = pd.read_csv('Horse.txt')
url_horse.to_csv('Horse.csv')
url_horse
# Out:
#     https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRrZXthw73EoHsK3Nx2qQHC246C_Y4W0llBgW-nHbOL3WvlTHwq
# 0    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4    https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                 ...
# 314  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 315  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 316  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 317  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 318  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [319 rows x 1 columns]

# %%
#downloading file for Donkey: https://drive.google.com/file/d/1Y2UHEj2p_Mnf70moXTddf7unA_7-Dvt4/view?usp=sharing

file_id = '1Y2UHEj2p_Mnf70moXTddf7unA_7-Dvt4'
downloaded = drive.CreateFile({'id': file_id})

downloaded.GetContentFile('Donkey.txt')  
url_horse = pd.read_csv('Donkey.txt')
url_horse.to_csv('Donkey.csv')
url_horse
# Out:
#     https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQVZlEe1fJYIoaIK8BxaCcYdA-HCFfyw3-Jc7_zITGdfHCU_ROa
# 0    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4    https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                 ...
# 314  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 315  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 316  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 317  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 318  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [319 rows x 1 columns]

# %%
from fastai.vision import *
classes = ['Mule', 'Horse', 'Donkey'] #Define Target classes for CNN to run

# %%
folder = 'Horse'
file = 'Horse.txt'

# %%
path = Path('/content/')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=300)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
folder = 'Mule'
file = 'Mule.txt'

# %%
path = Path('/content/')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=300)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
folder = 'Donkey'
file = 'Donkey.txt'

# %%
path = Path('/content/')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=300)
# Out:
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# Error  Invalid URL '': No schema supplied. Perhaps you meant http://?
# ...

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# Mule
# Horse
# Donkey

# %%
#!rm -rf <folder_name>

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Donkey', 'Horse', 'Mule']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Donkey', 'Horse', 'Mule'], 3, 576, 144)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.801354</td>
#       <td>1.049145</td>
#       <td>0.347222</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.339930</td>
#       <td>1.091132</td>
#       <td>0.375000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.166610</td>
#       <td>0.950519</td>
#       <td>0.312500</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.020871</td>
#       <td>0.917905</td>
#       <td>0.298611</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [9/12 00:56<00:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.731516</td>
#       <td>0.956359</td>
#       <td>0.298611</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.708352</td>
#       <td>0.977915</td>
#       <td>0.298611</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)
learn.fit_one_cycle(4)
learn.save('stage-3')
#learn_cln.load('stage-2');
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.520037</td>
#       <td>1.286072</td>
#       <td>0.291667</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.569519</td>
#       <td>1.375815</td>
#       <td>0.298611</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.575525</td>
#       <td>1.489267</td>
#       <td>0.305556</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.507919</td>
#       <td>1.200695</td>
#       <td>0.312500</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-3');
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
#ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
#ImageCleaner(ds, idxs, path)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [8/12 00:49<00:24]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %% [markdown]
# #Linear Regression SGD

# %%
# %matplotlib inline
from fastai.basics import *
n=100

# %%
x = torch.ones(n,2) 
x[:,0].uniform_(-1.,1)
x[:5]
# Out:
# tensor([[-0.8985,  1.0000],
#         [ 0.7291,  1.0000],
#         [ 0.0977,  1.0000],
#         [-0.9570,  1.0000],
#         [ 0.3721,  1.0000]])

# %%
a = tensor(3.,2); a
# Out:
# tensor([3., 2.])

# %%
y = x@a + torch.rand(n)
plt.scatter(x[:,0], y);

# %%
def mse(y_hat, y): return ((y_hat-y)**2).mean()

# %%
a = tensor(-1.,1)

# %%
y_hat = x@a

# %%
mse(y_hat, y)
# Out:
# tensor(6.4672)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],y_hat);

# %% [markdown]
# We would like to find the values of a that minimize mse_loss.
#
# Gradient descent is an algorithm that minimizes functions. Given a function defined by a set of parameters, gradient descent starts with an initial set of parameter values and iteratively moves toward a set of parameter values that minimize the function. This iterative minimization is achieved by taking steps in the negative direction of the function gradient.
#
# Here is gradient descent implemented in PyTorch.

# %%
a = nn.Parameter(a); a
# Out:
# Parameter containing:
# tensor([-1.,  1.], requires_grad=True)

# %%
from numpy import gradient as grad
def update():
    y_hat = x@a
    loss = mse(y, y_hat)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(lr * a.grad)
        a.grad.zero_()

# %%
lr = 1e-1
for t in range(100): update()
# Out:
# tensor(6.4672, grad_fn=<MeanBackward0>)
# tensor(1.6033, grad_fn=<MeanBackward0>)
# tensor(0.4935, grad_fn=<MeanBackward0>)
# tensor(0.2045, grad_fn=<MeanBackward0>)
# tensor(0.1288, grad_fn=<MeanBackward0>)
# tensor(0.1089, grad_fn=<MeanBackward0>)
# tensor(0.1037, grad_fn=<MeanBackward0>)
# tensor(0.1024, grad_fn=<MeanBackward0>)
# tensor(0.1020, grad_fn=<MeanBackward0>)
# tensor(0.1019, grad_fn=<MeanBackward0>)

# %%
#plt.scatter(x[:,0],y)
#plt.scatter(x[:,0],x@a);

# %%
#from matplotlib import animation, rc
#rc('animation', html='jshtml')

#a = nn.Parameter(tensor(-1.,1))

#fig = plt.figure()
#plt.scatter(x[:,0], y, c='orange')
#line, = plt.plot(x[:,0], x@a)
#plt.close()

#def animate(i):
#    update()
#    line.set_ydata(x@a)
#    return line,

#animation.FuncAnimation(fig, animate, np.arange(0, 100), interval=20)
